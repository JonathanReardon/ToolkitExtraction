# %%
##################################################
## GET INFORMATION FROM STRAND SPECIFIC STUDIES ##
##################################################

# import necessary libraries
import json
from collections import Counter
from pprint import pprint
from matplotlib import pyplot as plt
import pandas as pd
import seaborn
import csv
plt.style.use('ggplot')

# import dataset
with open('/home/jon/json/ToolkitExtraction/data/Batch1.json') as f:
    data=json.load(f)

# %%
def get_strand_info():
    ''' 
    a function that returns
    a dict containing strand labels
    and corresponding attribute ids
    '''
    strands={}
    for counter, element in enumerate(data["CodeSets"][0]["Attributes"]["AttributesList"]):
        attribute_name=(data["CodeSets"][0]["Attributes"]["AttributesList"][counter]["AttributeName"])
        attribute_id=(data["CodeSets"][0]["Attributes"]["AttributesList"][counter]["AttributeId"])
        strands.update( {attribute_id:attribute_name} )
    return strands

strands = get_strand_info()

def get_edu_info():
    edu_setting={}
    for counter, value in enumerate(data["CodeSets"][2]["Attributes"]["AttributesList"][2]["Attributes"]["AttributesList"][2]["Attributes"]["AttributesList"]):
        setting_code=data["CodeSets"][2]["Attributes"]["AttributesList"][2]["Attributes"]["AttributesList"][2]["Attributes"]["AttributesList"][counter]["AttributeId"]
        setting_name=data["CodeSets"][2]["Attributes"]["AttributesList"][2]["Attributes"]["AttributesList"][2]["Attributes"]["AttributesList"][counter]["AttributeName"]
        edu_setting.update( {setting_code:setting_name} )
    return edu_setting

edu = get_edu_info()

finds=[]

find=0
strandfind=0

studies=0
# iterate over each section within each study of 'references'
for section in range(len(data["References"])):
    studies+=1
    find=0
    strandfind=0
    for study in range(len(data["References"][section]["Codes"])):
        
        # get educational setting data (prmiary/elementary etc.)
        for key,value in edu.items():
            if key == data["References"][section]["Codes"][study]["AttributeId"]:
                find=value
                label=key
            elif find==0:
                find="NA"
                label="NA"
                
        # get strand data (feedback, peer tutoring etc.)
        for key,value in strands.items():
            if key == data["References"][section]["Codes"][study]["AttributeId"]:
                strandfind=value
                strandlabel=key
            elif strandfind==0:
                strandfind="NA"
                strandlabel="NA"
                
        # get outcome data
        if "Outcomes" in data["References"][section]:
            outcometext=data["References"][section]["Outcomes"][0]["OutcomeText"]
            interventiontext=data["References"][section]["Outcomes"][0]["InterventionText"]
            SMD=(data["References"][section]["Outcomes"][0]["SMD"])
            SESMD=(data["References"][section]["Outcomes"][0]["SESMD"])
            CIupperSMD=(data["References"][section]["Outcomes"][0]["CIUpperSMD"])
            CIlowerSMD=(data["References"][section]["Outcomes"][0]["CILowerSMD"])
        else:
            outcometext="NA"
            interventiontext="NA"
            SMD="NA"
            SESMD="NA"
            CIupperSMD="NA"
            CIlowerSMD="NA"
            
        # get year data
        if "Year" in data["References"][section]:
            year=data["References"][section]["Year"]
        else:
            year="NA"
            
        # get author data
        if "ShortTitle" in data["References"][section]:
            author=data["References"][section]["ShortTitle"]
        else:
            author="NA"
            
    finds.append([author, find, label, strandfind, strandlabel, interventiontext, 
                  outcometext, year, SMD, SESMD, CIupperSMD, CIlowerSMD])
    
df = pd.DataFrame(finds, columns=['Author', 'Edu Setting', 'Edu ID', 'Strand', 'Strand ID', 
# 17                     Feedback    5023555  Literacy: reading comprehension
# 18                Peer tutoring    5023548       Literacy: decoding/phonics
# 19  Oral language interventions    5023563          Literacy: reading other
# 20                Peer tutoring    5023548                      Mathematics
# 21  Oral language interventions    5023563                               NA
# 22  Oral language interventions    5023563  Literacy: reading comprehension
# 23  Oral language interventions    5023563                               NA
# 24  Oral language interventions    5023563          Literacy: reading other
# 25          Teaching assistants    5023576                 Cognitive: other
# 26                     Feedback    5023555                Literacy: writing
# 27                     Feedback    5023555                Literacy: writing
# 28  Oral language interventions    5023563  Literacy: reading comprehension
# 29                     Feedback    5023555                 Cognitive: other
# 30          Teaching assistants    5023576  Literacy: reading comprehension
# 31                     Feedback    5023555                      Mathematics
# 32           One to one tuition    5023562               Literacy: spelling
# 33          Teaching assistants    5023576  Literacy: reading comprehension
# 34                     Feedback    5023555                      Mathematics
# 35  Oral language interventions    5023563  Literacy: reading comprehension
# 36  Oral language interventions    5023563                               NA
# 37                     Feedback    5023555                               NA
# 38                     Feedback    5023555       Literacy: decoding/phonics
# 39  Oral language interventions    5023563                               NA
#
#                  Outcome  Year         SMD     SESMD  CI upper   CI lower
# 0                     NA  1997          NA        NA        NA         NA
# 1                     NA  1998          NA        NA        NA         NA
# 2        Primary outcome  2013     0.51742  0.176662  0.863677   0.171163
# 3        Primary outcome  1998       0.165     0.223   0.60208   -0.27208
# 4                     NA  1979          NA        NA        NA         NA
# 5        Primary outcome  1995      0.1596  0.124056   0.40275   -0.08355
# 6        Primary outcome  1971           0  0.294884  0.577972  -0.577972
# 7        Primary outcome  1984     1.66156  0.297138   2.24395    1.07917
# 8        Primary outcome  1973      1.1547  0.230978   1.60742   0.701984
# 9        Primary outcome  2008        0.83       0.2     1.222      0.438
# 10       Primary outcome  2004    0.362394  0.267265  0.886234  -0.161446
# 11       Primary outcome  2006   0.0396094  0.230985  0.492339   -0.41312
# 12       Primary outcome  1991     1.68702  0.401583   2.47413   0.899918
# 13                    NA  2000          NA        NA        NA         NA
# 14  Secondary outcome(s)  1994         0.3      0.18    0.6528    -0.0528
# 15       Primary outcome  1989    0.681418   0.33556   1.33911  0.0237214
# 16       Primary outcome  1963   -0.005847  0.145104  0.278556   -0.29025
# 17  Secondary outcome(s)  1990    0.654768  0.285477    1.2143  0.0952328
# 18       Primary outcome  2005      1.0958  0.343367    1.7688     0.4228
# 19       Primary outcome  1987   -0.175628  0.228865  0.272947  -0.624204
# 20       Primary outcome  1982      1.0033  0.387423   1.76265    0.24395
# 21                    NA  1992          NA        NA        NA         NA
# 22       Primary outcome  2002  -0.0698726  0.308711    0.5352  -0.674945
# 23                    NA  1982          NA        NA        NA         NA
# 24       Primary outcome  2007      1.1537  0.320592   1.78206   0.525335
# 25       Primary outcome  2013  0.00320974  0.436932  0.859596  -0.853177
# 26       Primary outcome  1979        0.22      0.12    0.4552    -0.0152
# 27       Primary outcome  1979    0.211533  0.145509  0.496731 -0.0736647
# 28       Primary outcome  1985    0.527072  0.366469   1.24535  -0.191208
# 29       Primary outcome  1982     0.85523   0.30271   1.44854   0.261917
# 30       Primary outcome  2015    0.164115  0.236212  0.627091  -0.298862
# 31       Primary outcome  1978     2.42889  0.405638   3.22394    1.63384
# 32       Primary outcome  2010     1.54686  0.294233   2.12355    0.97016
# 33  Secondary outcome(s)  2007           0     0.125     0.245     -0.245
# 34                        1970    0.519058  0.247946   1.00503  0.0330835
# 35       Primary outcome  2006         0.3      0.08    0.4568     0.1432
# 36                    NA  2006          NA        NA        NA         NA
# 37                    NA  1985          NA        NA        NA         NA
# 38       Primary outcome  1975        2.75      0.66    4.0436     1.4564
# 39                    NA  1967          NA        NA        NA         NA

# %%
# get attribute names and ids for "what is the educational setting?" from top-layer (codesets)
def get_edu_info():
    edu_setting=[]
    for counter, value in enumerate(data["CodeSets"][2]["Attributes"]["AttributesList"][2]["Attributes"]["AttributesList"][2]["Attributes"]["AttributesList"]):
        setting_code=data["CodeSets"][2]["Attributes"]["AttributesList"][2]["Attributes"]["AttributesList"][2]["Attributes"]["AttributesList"][counter]["AttributeId"]
        setting_name=data["CodeSets"][2]["Attributes"]["AttributesList"][2]["Attributes"]["AttributesList"][2]["Attributes"]["AttributesList"][counter]["AttributeName"]
        edu_setting.append(setting_code)
    return edu_setting[1]

edu = get_edu_info()
print(edu)
# Out:
# 5215411

# %%
######################################
### DISPLAY STRAND SUMMARY INFORMATION 
######################################
    
def get_strand_summary():
    '''
    A function that produces a basic
    summary of strand study counts
    and a graph to display them
    '''
    global counts, strand_title
    strand_overview=[]
    for element in range(len(data["References"])):
        for key, value in strands.items():
            for section in range(len(data["References"][element]["Codes"])):
                if key == data["References"][element]["Codes"][section]["AttributeId"]:
                    a=(data["References"][element]["ItemId"])
                    b=(data["References"][element]["Title"])
                    strand_overview.append([value, key, a, b])

    strand_title=[]
    for element in strand_overview:
        strand_title.append(element[0])
        
    print(len(strand_title))
    pprint(strand_title)

    counts = Counter(strand_title) 
    pprint(counts)

###################################################
### GET STRAND LABELS AND KEYS FROM TOP OUTER LAYER
###################################################

def get_strand_info():
    ''' 
    a function that returns
    a dict containing strand labels
    and corresponding attribute ids
    '''
    strands={}
    for counter, element in enumerate(data["CodeSets"][0]["Attributes"]["AttributesList"]):
        attribute_name=(data["CodeSets"][0]["Attributes"]["AttributesList"][counter]["AttributeName"])
        attribute_id=(data["CodeSets"][0]["Attributes"]["AttributesList"][counter]["AttributeId"])
        strands.update( {attribute_id:attribute_name} )
    return strands

#######################################
### GET THE ID FOR OUR STRAND OF CHOICE 
#######################################

def get_strand_value(strand_label):
    ''' 
    A function that takes in a 
    strand name and returns
    the strand ID
    '''
    for key, value in strands.items():
        if value == strand_label:
            return key, value

######################################################
###  GET EFFECT SIZE INFO FROM STRAND SPECIFIC STUDIES
######################################################

def get_data(strand_key, strand_value, outcome_choice):
    '''
    A function that accepts a strand id and a variable of
    interest and returns a list of that id and the variable
    values.
    '''
    outcome_studies=[] 

    # iterate over each study of 'references'
    for section in range(len(data["References"])):
        # iterate over each section within each study of 'references'
        for study in range(len(data["References"][section]["Codes"])):
            # check each study to see if strand id is present
            if strand_id[0] == data["References"][section]["Codes"][study]["AttributeId"]:
                if "Outcomes" in data["References"][section]:
                    if data["References"][section]["Outcomes"][0]["OutcomeText"] == outcome_choice:
                        outcome_id=((data["References"][section]["Outcomes"][0]["OutcomeId"]))
                        outcome_type=(data["References"][section]["Outcomes"][0]["ShortTitle"])
                        outcome_text=(data["References"][section]["Outcomes"][0]["OutcomeText"])
                        SMD=(data["References"][section]["Outcomes"][0]["SMD"])
                        SESMD=(data["References"][section]["Outcomes"][0]["SESMD"])
                        year=(data["References"][section]["Year"])
                        intervention=(data["References"][section]["Outcomes"][0]["InterventionText"])
                        outcome_studies.append([strand_key, strand_value, outcome_id, outcome_text, outcome_type, year, intervention, SMD, SESMD])
              
    # display number of studies found within selected strand
    print("Number of studies:", len(outcome_studies), "\n")
    print("schools", schools)
    print("strands", strands)
    print("with outcome", with_outcome)
    
    pd.set_option('display.max_rows', None)
    
    # convert data list to pandas dataframe for viewing
    df = pd.DataFrame(outcome_studies, columns=['AttributeId', 'Strand', 'OutcomeId', 'OutcomeType', 'ShortTitle', 'Year', 'Intervention', 'SMD', 'SESMD'])
    display(df.head(len(df)))

# %%
strands = get_strand_info()
strand_id = get_strand_value("Feedback") # select strand
get_data(strand_id[0], strand_id[1], "Primary outcome")
# Out:
# Number of studies: 89
#
# schools 0
# strands 108
# with outcome 108
#     AttributeId    Strand  OutcomeId      OutcomeType  \
# 0       5023555  Feedback      46356  Primary outcome
# 1       5023555  Feedback      49729  Primary outcome
# 2       5023555  Feedback      46229  Primary outcome
# 3       5023555  Feedback      47394  Primary outcome
# 4       5023555  Feedback      46370  Primary outcome
# 5       5023555  Feedback      49773  Primary outcome
# 6       5023555  Feedback      48085  Primary outcome
# 7       5023555  Feedback      48088  Primary outcome
# 8       5023555  Feedback      46278  Primary outcome
# 9       5023555  Feedback      48104  Primary outcome
# 10      5023555  Feedback      48142  Primary outcome
# 11      5023555  Feedback      46384  Primary outcome
# 12      5023555  Feedback      47541  Primary outcome
# 13      5023555  Feedback      48123  Primary outcome
# 14      5023555  Feedback      48143  Primary outcome
# 15      5023555  Feedback      49733  Primary outcome
# 16      5023555  Feedback      46656  Primary outcome
# 17      5023555  Feedback      46659  Primary outcome
# 18      5023555  Feedback      46661  Primary outcome
# 19      5023555  Feedback      47112  Primary outcome
# 20      5023555  Feedback      47114  Primary outcome
# 21      5023555  Feedback      46186  Primary outcome
# 22      5023555  Feedback      46876  Primary outcome
# 23      5023555  Feedback      46259  Primary outcome
# 24      5023555  Feedback      46361  Primary outcome
# 25      5023555  Feedback      46914  Primary outcome
# 26      5023555  Feedback      46820  Primary outcome
# 27      5023555  Feedback      46365  Primary outcome
# 28      5023555  Feedback      44711  Primary outcome
# 29      5023555  Feedback      46607  Primary outcome
# 30      5023555  Feedback      46387  Primary outcome
# 31      5023555  Feedback      46945  Primary outcome
# 32      5023555  Feedback      47868  Primary outcome
# 33      5023555  Feedback      46961  Primary outcome
# 34      5023555  Feedback      47185  Primary outcome
# 35      5023555  Feedback      47121  Primary outcome
# 36      5023555  Feedback      44712  Primary outcome
# 37      5023555  Feedback      44713  Primary outcome
# 38      5023555  Feedback      44918  Primary outcome
# 39      5023555  Feedback      49740  Primary outcome
# 40      5023555  Feedback      45082  Primary outcome
# 41      5023555  Feedback      44940  Primary outcome
# 42      5023555  Feedback      44964  Primary outcome
# 43      5023555  Feedback      47120  Primary outcome
# 44      5023555  Feedback      44965  Primary outcome
# 45      5023555  Feedback      45059  Primary outcome
# 46      5023555  Feedback      49747  Primary outcome
# 47      5023555  Feedback      46751  Primary outcome
# 48      5023555  Feedback      45078  Primary outcome
# 49      5023555  Feedback      47873  Primary outcome
# 50      5023555  Feedback      47878  Primary outcome
# 51      5023555  Feedback      47882  Primary outcome
# 52      5023555  Feedback      45055  Primary outcome
# 53      5023555  Feedback      45058  Primary outcome
# 54      5023555  Feedback      46795  Primary outcome
# 55      5023555  Feedback      47942  Primary outcome
# 56      5023555  Feedback      48043  Primary outcome
# 57      5023555  Feedback      46919  Primary outcome
# 58      5023555  Feedback      48044  Primary outcome
# 59      5023555  Feedback      46805  Primary outcome
# 60      5023555  Feedback      45326  Primary outcome
# 61      5023555  Feedback      46834  Primary outcome
# 62      5023555  Feedback      47487  Primary outcome
# 63      5023555  Feedback      47533  Primary outcome
# 64      5023555  Feedback      47589  Primary outcome
# 65      5023555  Feedback      48202  Primary outcome
# 66      5023555  Feedback      47492  Primary outcome
# 67      5023555  Feedback      47560  Primary outcome
# 68      5023555  Feedback      48428  Primary outcome
# 69      5023555  Feedback      48218  Primary outcome
# 70      5023555  Feedback      47224  Primary outcome
# 71      5023555  Feedback      48287  Primary outcome
# 72      5023555  Feedback      46962  Primary outcome
# 73      5023555  Feedback      48000  Primary outcome
# 74      5023555  Feedback      49767  Primary outcome
# 75      5023555  Feedback      46955  Primary outcome
# 76      5023555  Feedback      47531  Primary outcome
# 77      5023555  Feedback      49768  Primary outcome
# 78      5023555  Feedback      46872  Primary outcome
# 79      5023555  Feedback      47515  Primary outcome
# 80      5023555  Feedback      45319  Primary outcome
# 81      5023555  Feedback      45318  Primary outcome
# 82      5023555  Feedback      45312  Primary outcome
# 83      5023555  Feedback      45287  Primary outcome
# 84      5023555  Feedback      47068  Primary outcome
# 85      5023555  Feedback      47065  Primary outcome
# 86      5023555  Feedback      45281  Primary outcome
# 87      5023555  Feedback      45223  Primary outcome
# 88      5023555  Feedback      45336  Primary outcome
#
#                   ShortTitle  Year  \
# 0               Adler (1998)  1998
# 1            Anderson (1973)  1973
# 2             Andrade (2008)  2008
# 3            Aumiller (1963)  1963
# 4          Benson (1979) 1_1  1979
# 5          Benson (1979) 1_2  1979
# 6              Bethge (1982)  1982
# 7              Bilsky (1978)  1978
# 8            Bohannon (1975)  1975
# 9          Boulet (1990) 1_1  1990
# 10         Boulet (1990) 1_2  1990
# 11   Brandstetter (1978) 1_1  1978
# 12   Brandstetter (1978) 1_2  1978
# 13      Bridgeman (1974) 1_1  1974
# 14      Bridgeman (1974) 1_2  1974
# 15          Brookhart (2008)  2010
# 76                                         Science  0.700000  0.400000
# 77                                     Mathematics  0.080000  0.081340
# 78                              Literacy: spelling  0.740000  1.700000
# 79                                         Science  0.600000  0.400000
# 80                               Literacy: writing  0.610201  0.284248
# 81                               Curriculum: other -0.313327  0.225045
# 82                               Curriculum: other  0.320000  0.081600
# 83                               Literacy: writing  0.656447  0.220734
# 84                               Literacy: writing  0.957676  0.507558
# 85                               Literacy: writing  0.925988  0.489468
# 86                                         Science -0.323332  0.126337
# 87                               Literacy: writing  1.280690  0.173465
# 88                                Cognitive: other  1.332397  0.665930

# %%
def get_edu_info():
    edu_setting={}
    for counter, value in enumerate(data["CodeSets"][2]["Attributes"]["AttributesList"][2]["Attributes"]["AttributesList"][2]["Attributes"]["AttributesList"]):
        setting_code=data["CodeSets"][2]["Attributes"]["AttributesList"][2]["Attributes"]["AttributesList"][2]["Attributes"]["AttributesList"][counter]["AttributeId"]
        setting_name=data["CodeSets"][2]["Attributes"]["AttributesList"][2]["Attributes"]["AttributesList"][2]["Attributes"]["AttributesList"][counter]["AttributeName"]
        edu_setting.update( {setting_code:setting_name} )
    return edu_setting

edu = get_edu_info()

schools=[]
no=0
sections=0
studies=0
for section in range(len(data["References"])):
        sections+=1
        # iterate over each section within each study of 'references'
        for study in range(len(data["References"][section]["Codes"])):
            studies+=1
            for key, value in edu.items():
                if key == data["References"][section]["Codes"][study]["AttributeId"]:
                    schools.append(value)
                else:
                    no+=1
                    
print(len(schools))
print("false checks", no)
print("sections:", sections)
print("studies:", studies)
pprint(schools)

print(edu.keys())
# Out:
# 471
# false checks 320168
# sections: 447
# studies: 29149
# ['Primary/elementary school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Middle school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Middle school',
#  'Primary/elementary school',
#  'Nursery school/pre-school',
#  'Nursery school/pre-school',
#  'Middle school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Middle school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Nursery school/pre-school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Middle school',
#  'Middle school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Middle school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Middle school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Nursery school/pre-school',
#  'Nursery school/pre-school',
#  'Middle school',
#  'Primary/elementary school',
#  'Middle school',
#  'Secondary/High school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Middle school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Middle school',
#  'Secondary/High school',
#  'Middle school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Nursery school/pre-school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Nursery school/pre-school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Middle school',
#  'Secondary/High school',
#  'Middle school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Middle school',
#  'Middle school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Middle school',
#  'Secondary/High school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Nursery school/pre-school',
#  'Nursery school/pre-school',
#  'Primary/elementary school',
#  'Nursery school/pre-school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Middle school',
#  'Middle school',
#  'Primary/elementary school',
#  'Middle school',
#  'No information provided',
#  'Primary/elementary school',
#  'Middle school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Nursery school/pre-school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Middle school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Middle school',
#  'Primary/elementary school',
#  'Nursery school/pre-school',
#  'Nursery school/pre-school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Middle school',
#  'Other educational setting (please specify)',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Other educational setting (please specify)',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Independent/private school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Further education/junior or community college',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Middle school',
#  'Middle school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Nursery school/pre-school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Middle school',
#  'Secondary/High school',
#  'Secondary/High school',
#  'Nursery school/pre-school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Nursery school/pre-school',
#  'Nursery school/pre-school',
#  'Primary/elementary school',
#  'Middle school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Middle school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Middle school',
#  'Middle school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Middle school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Middle school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Middle school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Nursery school/pre-school',
#  'No information provided',
#  'Primary/elementary school',
#  'Middle school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Nursery school/pre-school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Nursery school/pre-school',
#  'Nursery school/pre-school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Middle school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Middle school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Middle school',
#  'Other educational setting (please specify)',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Nursery school/pre-school',
#  'Primary/elementary school',
#  'Other educational setting (please specify)',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Other educational setting (please specify)',
#  'Primary/elementary school',
#  'Independent/private school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Nursery school/pre-school',
#  'Nursery school/pre-school',
#  'Primary/elementary school',
#  'Other educational setting (please specify)',
#  'Nursery school/pre-school',
#  'Nursery school/pre-school',
#  'Middle school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Nursery school/pre-school',
#  'Home',
#  'Primary/elementary school',
#  'Middle school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Nursery school/pre-school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Middle school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Secondary/High school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Middle school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Middle school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Nursery school/pre-school',
#  'Primary/elementary school',
#  'Other educational setting (please specify)',
#  'Nursery school/pre-school',
#  'Nursery school/pre-school',
#  'Other educational setting (please specify)',
#  'Primary/elementary school',
#  'Nursery school/pre-school',
#  'Secondary/High school',
#  'Residential/boarding school',
#  'Primary/elementary school',
#  'No information provided',
#  'Primary/elementary school',
#  'Nursery school/pre-school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Middle school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Middle school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Nursery school/pre-school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Nursery school/pre-school',
#  'Home',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Middle school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Nursery school/pre-school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Nursery school/pre-school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Middle school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Nursery school/pre-school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Nursery school/pre-school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Secondary/High school',
#  'Nursery school/pre-school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Nursery school/pre-school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Nursery school/pre-school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Independent/private school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Nursery school/pre-school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Further education/junior or community college',
#  'Primary/elementary school',
#  'Middle school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Middle school',
#  'Middle school',
#  'Further education/junior or community college',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Nursery school/pre-school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Primary/elementary school',
#  'Middle school',
#  'Nursery school/pre-school',
#  'Nursery school/pre-school',
#  'Primary/elementary school',
#  'Nursery school/pre-school',
#  'Nursery school/pre-school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Middle school',
#  'Nursery school/pre-school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Secondary/High school',
#  'Middle school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Middle school',
#  'Nursery school/pre-school',
#  'Primary/elementary school',
#  'Middle school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Primary/elementary school',
#  'Middle school',
#  'Primary/elementary school',
#  'Primary/elementary school']
# dict_keys([5215410, 5215411, 5215412, 5215413, 5215414, 5215415, 5215416, 5215566, 5215417, 5215418, 5513033])

# %%
# Out:
# 480
